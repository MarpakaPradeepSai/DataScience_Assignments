# %%
import pandas as pd
import requests
from tqdm import tqdm_notebook
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings("ignore")

# %%
headers = {
    'authority': 'www.amazon.in',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'max-age=0',
    # Requests sorts cookies= alphabetically
    # 'cookie': 'session-id=259-3113978-6678618; i18n-prefs=INR; ubid-acbin=260-8554202-6973909; lc-acbin=en_IN; csm-hit=tb:BS866TA0AKH6X86N924E+sa-7XYTQAXQHJP5ADH88228-DY27HYE0CK5V9FW24GBD|1656009294944&t:1656009294945&adb:adblk_yes; session-token=Z1j175VoYxPr2Un/9ciL3Q6lKw+QtLYYIwSQ+GLxjT06952u8vOZromD4WcFE0bs+yrUyLPy8HmIn7mTjUt8qsx3n0meC7yWKFqqwDEm5iecYedklsrNwmDrQOiaMH9lpacbdB8kgUk5IbZdg1VyhrdnY4OZrk6r350ARDEXJExuu2GZr0sV4fpbwUes/V9fDrfASeMQhVEEzmEAAHWN2g==; session-id-time=2082758401l',
    'device-memory': '8',
    'downlink': '10',
    'dpr': '0.8',
    'ect': '4g',
    'referer': 'https://www.amazon.in/Apple-iPhone-Pro-Max-256/dp/B0CHX1K2ZC/ref=sr_1_1_sspa?crid=2MI38GB6WQS1C&keywords=iphone+15+pro+max&qid=1706787559&sprefix=iphhone%2Caps%2C249&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&psc=1',
    'rtt': '0',
    'sec-ch-device-memory': '8',
    'sec-ch-dpr': '0.8',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="102", "Google Chrome";v="102"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-viewport-width': '2400',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'service-worker-navigation-preload': 'true',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36',
    'viewport-width': '2400',
}

# %%
def get_soup(url):
    #r = requests.get('http://localhost:8050/render.html',
    # Run this instead if you haven't setup Splash & Docker
    r = requests.get(url, headers=headers,
    params={'url': url, 'wait': 2})
    soup = BeautifulSoup(r.text, 'html.parser')
    return soup

# %%
# Initialize list to store reviews data later on
reviewlist = []

# Function 2: look for web-tags in our soup, then append our data to reviewList
def get_reviews(soup):
    reviews = soup.find_all('div', {'data-hook': 'review'})
    try:
        for item in reviews:
            review = {
            'product': soup.title.text.replace('Amazon.in:Customer reviews: ', '').strip(),
            'date': item.find('span', {'data-hook': 'review-date'}).text.replace('Reviewed in India on', '').strip(),
            'title': item.find('a', {'data-hook': 'review-title'}).text.strip(),
            'rating':  float(item.find('i', {'data-hook': 'review-star-rating'}).text.replace('out of 5 stars', '').strip()),
            'body': item.find('span', {'data-hook': 'review-body'}).text.strip(),
            }
            reviewlist.append(review)
    except:
        pass

# %%
# Initialize list to store reviews data later on
reviewlist = []

# Function 2: look for web-tags in our soup, then append our data to reviewList
def get_reviews(soup):
    reviews = soup.find_all('div', {'data-hook': 'review'})
    try:
        for item in reviews:
            review = {
            'Rating':  float(item.find('i', {'data-hook': 'review-star-rating'}).text.replace('out of 5 stars', '').strip()),
            'Title': item.find('a', {'data-hook': 'review-title'}).text.strip(),
            'Review': item.find('span', {'data-hook': 'review-body'}).text.strip(),
            }
            reviewlist.append(review)
    except:
        pass

# %%
# loop through 1:x many pages, or until the css selector found only on the last page is found (when the next page button is greyed)
for x in tqdm_notebook(range(1,1000)):
    soup = get_soup(f'https://www.amazon.in/product-reviews/B0CHXCWTMW?ref=ods_ucc_cust_kindle_B0CHXCWTMW_nrc_ucc/\
    ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber={x}')
    #print(f'Getting page: {x}')
    get_reviews(soup)
    #print(len(reviewlist))
    if not soup.find('li', {'class': 'a-disabled a-last'}):
        pass
    else:
        break
# Out:
#   0%|          | 0/999 [00:00<?, ?it/s]

# %%
# Save results to a dataframe, then export as CSV
df = pd.DataFrame(reviewlist)
df
# Out:
#     Rating                                              Title  \
# 0      5.0  5.0 out of 5 stars\nGood Mobile (If you have b...
# 1      5.0   5.0 out of 5 stars\nAmazing Lightning fast phone
# 2      5.0          5.0 out of 5 stars\nBest Smart Phone ever
# 3      5.0                5.0 out of 5 stars\nNam hi kafi hai
# 4      5.0  5.0 out of 5 stars\nAwesome camera and best qu...
# ..     ...                                                ...
# 56     5.0    5.0 out of 5 stars\nBeast Gadget with PROS CONS
# 57     5.0              5.0 out of 5 stars\nWorth the upgrade
# 58     5.0              5.0 out of 5 stars\nLove this pro max
# 59     1.0                  1.0 out of 5 stars\n12345santhosh
# 60     5.0                  5.0 out of 5 stars\nMy experience
#
#                                                Review
# 0   As I was aware that what I need and what I was...
# 1   The phone is really good it had some overheati...
# 2   It’s a fantastic phone…the feel and comfort in...
# 3   Ultimate performance but some bug issue in 17....
# 4   I recently switched from android to iphone. So...
# ..                                                ...
# 56  Pros :Light weighted ~ My XR weighted more tha...
# 57  The aluminium has made the phone very light we...
# 58                              best iphone ever used
# 59  Compare to iphone 14 pro max 15 pro max is ver...
# 60  I like all the things in iphone 15 Promax the ...
#
# [61 rows x 3 columns]

# %%
df.to_csv("reviews.csv", index = False)
